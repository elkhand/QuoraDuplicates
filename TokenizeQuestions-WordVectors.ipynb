# %% [markdown]
# setup:
#
# * pip install ipython-autotime
# * pip install pyenchant

# %%
import nltk
# nltk.download() #punkt

# %%
# %load_ext autotime
# %pylab inline
from __future__ import unicode_literals
import pandas as pd
import multiprocessing as mp
# from nltk.tokenize.stanford import StanfordTokenizer
import sys, re, json, csv, time, pickle
sys.path.append('quora-duplicates/')
import enchant
from enchant.checker import SpellChecker
# from utils.spellcheck import spell_check
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# Populating the interactive namespace from numpy and matplotlib
# time: 137 ms
# /Users/kyu/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
print 'loading data...'
quora = pd.read_csv('data/quora_duplicate_questions.tsv', sep='\t', encoding='utf-8')
print quora.shape
quora.head(2)
# Out:
# loading data...
# (404351, 6)
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# time: 3.9 s

# %%
quora.is_duplicate.value_counts()/float(quora.shape[0])
# Out:
# 0    0.630752
# 1    0.369248
# Name: is_duplicate, dtype: float64
# time: 8.25 ms

# %% [markdown]
# ## Spell-checker

# %%
# https://www.packtpub.com/mapt/book/application-development/9781782167853/2/ch02lvl1sec23/spelling-correction-with-enchant
import enchant
from nltk.metrics import edit_distance

class SpellingReplacer(object):
  def __init__(self, dict_name='en', max_dist=2):
    self.spell_dict = enchant.Dict(dict_name)
    self.max_dist = max_dist

  def replace(self, words):
    corrected_words = list()
    for word in words:
        if self.spell_dict.check(word):
            corrected_words.append(word)
            continue
        suggestions = self.spell_dict.suggest(word)
        if suggestions and edit_distance(word, suggestions[0]) <= self.max_dist:
          corrected_words.append(suggestions[0])
        else:
          corrected_words.append(word)
    return corrected_words
# Out:
# time: 8.65 ms

# %%
replacer = SpellingReplacer()
# Out:
# time: 31.4 ms

# %% [markdown]
# ## Tokenizations

# %%
# define tokenizer
# jar_path = '/Users/katherineyu/tools/stanford-postagger-2016-10-31/stanford-postagger.jar'
# model_path = '/Users/katherineyu/tools/stanford-postagger-2016-10-31/models/english-bidirectional-distsim.tagger'
# tokenizer = StanfordTokenizer(path_to_jar=jar_path, encoding='utf8', options=None, verbose=True, java_options='-mx2000m')
# print tokenizer.tokenize('Hello world.')
# Out:
# time: 1.53 ms

# %%
# load glove pretrained vectors
gl = pd.read_csv('glove/glove.6B.100d.txt', header=None, sep='\s+', error_bad_lines=False, quoting=csv.QUOTE_NONE, encoding='utf8')
gl_vocab = gl.pop(0)
gl_vocab_index = pd.DataFrame({'vocab_idx': gl_vocab.index})
gl_vocab_index.index = gl_vocab.values
print gl_vocab.shape, gl.shape
gl_vocab_index.head(5)
# Out:
# (400000,) (400000, 100)
#      vocab_idx
# the          0
# ,            1
# .            2
# of           3
# to           4
# time: 10.7 s

# %%
from nltk.tokenize.stanford import StanfordTokenizer
from nltk.tokenize import word_tokenize
import string
class TokenizerWorker(object):
    
    def __init__(self, gl_vocab_index, gl, spellreplacer):
#         self.tokenizer = tokenizer
        self.gl_vocab_index = gl_vocab_index
        self.gl = gl
        self.spellreplacer = spellreplacer
    
    def tokenize(self, s):
#         tokens = self.tokenizer.tokenize(s)
#         tokens =  re.findall(r"[\w']+", s)
        try:
            s = re.sub(r'[^\w\s]','', s.encode('utf-8').lower())
        except:
            return [s]
        tokens = word_tokenize(s) # lower and strip punctuation
        tokens_postprocess = tokens
        return tokens_postprocess
    
    def __call__(self, s):

        tokens = self.tokenize(s)
        s_vect = np.zeros((1, self.gl.shape[1]))
        missing_word = False
        
        for word in tokens: # sum glove vectors
            try:
                s_vect += self.gl.iloc[self.gl_vocab_index.ix[word], :]
            except KeyError:
                missing_word = True
            except TypeError:
                continue
        
        if missing_word: # rerun with spellcheck
            tokens = self.spellreplacer.replace(tokens)
            s_vect = np.zeros((1, self.gl.shape[1]))
            for word in tokens:
                try:
                    s_vect += self.gl.iloc[self.gl_vocab_index.ix[word], :]
                except (KeyError, TypeError) as e:
                    pass
            s = ' '.join(tokens)

        return (s, s_vect)
# Out:
# time: 23.9 ms

# %%
# test the token match without spell_check
n = 100
match_ct = 0
nonmatch_ct = 0
tot_nonmatch_ct = 0

tokenizer_worker = TokenizerWorker(gl_vocab_index, gl, replacer)
for s in quora['question1'].values[:n]:
    s_vect = np.zeros((1, gl.shape[1]))
    tokens = tokenizer_worker.tokenize(s)
    has_match = False
    for word in tokens:
        if word in gl_vocab_index.index:
            s_vect += gl.iloc[gl_vocab_index.ix[word], :]
            match_ct += 1
            has_match = True
        else:
            nonmatch_ct += 1
            print s
            print word
    if not has_match:
        tot_nonmatch_ct += 1
print match_ct, nonmatch_ct, nonmatch_ct/(match_ct + nonmatch_ct + 0.0), tot_nonmatch_ct
# Out:
# Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
# quikly
# Astrology: I am a Capricorn Sun Cap moon and cap rising...what does that say about me?
# risingwhat
# Motorola (company): Can I hack my Charter Motorolla DCX3400?
# motorolla
# Motorola (company): Can I hack my Charter Motorolla DCX3400?
# dcx3400
# Method to find separation of slits using fresnel biprism?
# biprism
# I'm a 19-year-old. How can I improve my skills or what should I do to become an entrepreneur in the next few years?
# 19yearold
# What universities does Rexnord recruit new grads from? What majors are they looking for?
# rexnord
# What is the best/most memorable thing you've ever eaten and why?
# bestmost
# What is the best/most memorable thing you've ever eaten and why?
# youve
# Who is israil friend?
# israil
# How do I download content from a kickass torrent without registration?
# kickass
# What were the major effects of the cambodia earthquake, and how do these effects compare to the Kamchatca earthquakes in 1952?
# kamchatca
# National Institute of Technology, Kurukshetra: How is the social life at NITK, Surathkal?
# nitk
# Why is the number for Skype at 1-855-425-3768 always busy?
# 18554253768
# 1098 14 0.0125899280576 0
# time: 1.01 s

# %%
# test spellcheck
input1 = "Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?"
tokenizer_worker = TokenizerWorker(gl_vocab_index, gl, replacer)
replacer.replace(tokenizer_worker.tokenize(input1))
# Out:
# [u'which',
#  u'one',
#  u'dissolve',
#  u'in',
#  u'water',
#  u'quickly',
#  u'sugar',
#  u'salt',
#  u'methane',
#  u'and',
#  u'carbon',
#  u'id',
#  u'oxide']
# time: 107 ms

# %%
# test run
replacer = SpellingReplacer()
tokenizer_worker = TokenizerWorker(gl_vocab_index, gl, replacer)
zip(*quora.question1[:10000].map(tokenizer_worker))
# Out:
# [(u'What is the step by step guide to invest in share market in india?',
#   u'What is the story of Kohinoor (Koh-i-Noor) Diamond?',
#   u'How can I increase the speed of my internet connection while using a VPN?',
#   u'Why am I mentally very lonely? How can I solve it?',
#   u'which one dissolve in water quickly sugar salt methane and carbon id oxide',
#   u'astrology I am a Capricorn sun cap moon and cap rising what does that say about me',
#   u'Should I buy tiago?',
#   u'How can I be a good geologist?',
#   u'When do you use \u30b7 instead of \u3057?',
#   u'Motorola company can I hack my charter Motorola dcx3400',
#   u'method to find separation of slits using Fresnel bi prism',
#   u'How do I read and find my YouTube comments?',
#   u'What can make Physics easy to learn?',
#   u'What was your first sexual experience like?',
#   u'What are the laws to change your status from a student visa to a green card in the US, how do they compare to the immigration laws in Canada?',
#   u'What would a Trump presidency mean for current international master\u2019s students on an F1 visa?',
#   u'What does manipulation mean?',
#   u'Why do girls want to be friends with the guy they reject?',
#   u'Why are so many Quora users posting questions that are readily answered on Google?',
#   u'Which is the best digital marketing institution in banglore?',
#   u'Why do rockets look white?',
#   u"What's causing someone to be jealous?",
#   u'What are the questions should not ask on Quora?',
#   u'How much is 30 kV in HP?',
#   u'What does it mean that every time I look at the clock the numbers are the same?',
#   u'What are some tips on making it through the job interview process at Medicines?',
#   u'What is web application?',
#   u'Does society place too much importance on sports?',
#   u'What is best way to make money online?',
#   u'How should I prepare for CA final law?',
#   u"What's one thing you would like to do better?",
#   u'What are some special cares for someone with a nose that gets stuffy during the night?',
#   u'What Game of Thrones villain would be the most likely to give you mercy?',
#   u'Does the United States government still blacklist (employment, etc.) some United States citizens because their political views?',
#   u'What is the best travel website in spain?',
#   u'Why do some people think Obama will try to take their guns away?',
#   u'mi a 19yearold how can I improve my skills or what should I do to become an entrepreneur in the next few years',
#   u'When a girlfriend asks her boyfriend "Why did you choose me? What makes you want to be with me?", what should one reply to her?',
#   u'How do we prepare for UPSC?',
#   u'What is the stall speed and AOA of an f-14 with wings fully swept back?',
#   u'Why do Slavs squat?',
#   u'When can I expect my Cognizant confirmation mail?',
#   u'Can I make 50,000 a month by day trading?',
#   u'Is being a good kid and not being a rebel worth it in the long run?',
#   u'what universities does rexnord recruit new drags from what majors are they looking for',
#   u'What is the quickest way to increase Instagram followers?',
#   u'How did Darth Vader fought Darth Maul in Star Wars Legends?',
#   u'What are the stages of breaking up between couple? I mean, what happens after the breaking up emotionally whether its a male or female?',
#   u'What are some examples of products that can be make from crude oil?',
#   u'How do I make friends.',
#   u'Is Career Launcher good for RBI Grade B preparation?',
#   u'Will a Blu Ray play on a regular DVD player? If so, how?',
#   u'Nd she is always sad?',
#   u"what is the best most memorable thing you've ever eaten and why",
#   u'How GST affects the CAs and tax officers?',
#   u'How difficult is it get into RSI?',
#   u'who is is rail friend',
#   u'What are some good rap songs to dance to?',
#   u"I was suddenly logged off Gmail. I can't remember my Gmail password and just realized the recovery email is no longer alive. What can I do?",
#   u'What are the best ways to learn French?',
#   u'how do I download content from a kick ass torrent without registration',
#   u'Is it normal to have a dark ring around the iris of my eye?',
#   u"How is the new Harry Potter book 'Harry Potter and the Cursed Child'?",
#   u'Why do I always get depressed?',
#   u'Where can I find a European family office database?',
#   u'What is Java programming? How To Learn Java Programming Language ?',
#   u'What is the best book ever made?',
#   u'Can we ever store energy produced in lightning?',
#   u'What is your review of Performance Testing?',
#   u'At what cost does so much privacy as in Germany come? What else is lost to gain so much privacy?',
#   u'What are the types of immunity?',
#   u'What is a narcissistic personality disorder?',
#   u'How I can speak English fluently?',
#   u"How helpful is QuickBooks' auto data recovery support phone number to recover your corrupted data files?",
#   u'Who is the richest gambler of all time and how can I reach his level?',
#   u'If I fire a bullet backward from an aircraft going faster than the bullet; will the bullet be going backwards?',
#   u'How do I prevent breast cancer?',
#   u"How do I log out of my Gmail account on my friend's phone?",
#   u'How can I make money through the Internet?',
#   u'What is purpose of life?',
#   u"When will the BJP government strip all the Muslims and the Christians of the Indian citizenship and put them on boats like the Rohingya's of Burma?",
#   u'What is the right etiquette for wishing a Jehovah Witness happy birthday?',
#   u'If someone wants to open a commercial FM radio station in any city of India, how much does it cost and what is the procedure?',
#   u'Why do Swiss despise Asians?',
#   u'What are some of the high salary income jobs in the field of biotechnology?',
#   u'How can I increase my height after 21 also?',
#   u'what were the major effects of the Cambodia earthquake and how do these effects compare to the kamchatca earthquakes in 1952',
#   u'What is the difference between sincerity and fairness?',
#   u'Which is the best gaming laptop under 60k INR?',
#   u'What is your review of The Next Warrior: Proving Grounds - Part 9?',
#   u'What is the best reference book for physics class 11th?',
#   u'national institute of technology kurukshetra how is the social life at nit surathkal',
#   u'What are some of the best romantic movies in English?',
#   u'What causes a nightmare?',
#   u'What is abstract expressionism in painting?',
#   u'How does 3D printing work?',
#   u'What was it like to attend Caltech with Jeremy Ehrhardt?',
#   u'Why did harry become a horcrux?',
#   u'What are the best associate product manager (APM) programs that someone in their early 20s can join to learn product management and have a rewarding career in the company?',
#   u'why is the number for Skye at 18554253768 always busy',
#   u'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?',
#   u'Did Ronald Reagan have a mannerism in his speech?',
#   u'What were the war strategies of the Union and the Confederates during the Civil War?',
#   u'Which is the best fiction novel of 2016?',
#   u'Can I recover my email if I forgot the password?',
#   u'will the recent demonetisation results in higher gdp if so how much',
#   u'Have you ever heard of travel hacking?',
#   u"What's the difference between love and pity?",
#   u'How competitive is the hiring process at Republic Bank?',
#   u'How Google helps in spam ranking adjustment of the search results?',
#   u'where can I watch gonulcelen with English subtitles',
#   u'Is USA the most powerful country of the world?',
#   u'How do you obtain an instant ulcer pain relief?',
#   u'What do you think China food?',
#   u'What does taking advantage of someone mean?',
#   u'Why do we cry when we are happy and when we are sad?',
#   u'Why do some girls like to stick their their tongues out when taking pictures?',
#   u'Did you find the ending of the novel "1984" depressing?',
#   u"What are some mind-blowing computer tools that exist that most people don't know about?",
#   u'Should the toothbrush be wet or dry before applying the toothpaste?',
#   u'why my question was marked as needing improvement',
#   u'What is the difference between a neutral state and a buffer state?',
#   u'What mineral holds the highest electrical charge?',
#   u'What is the greatest mystery in the universe?',
#   u'What is the alternative to machine learning?',
#   u'why does china block sanctions at the UN against the jaishemohammad em chief mason azhar',
#   u'What is the mean of future budget?',
#   u'Can excessive amounts of Vitamin C cause me to have a miscarriage?',
#   u'What is it like to work in Asahi India Glass? What will be the pay scale after one or two years?',
#   u'how do I access tor box in India',
#   u'what are some yakshini mantras',
#   u'Was six party talks successful?',
#   u'How do I register my domain site email?',
#   u'Is it normal for older men to be attracted to young women?',
#   u'What is the strongest structure or strongest shape under compression?',
#   u'Who are the Rohingya Muslims?',
#   u'Does it matter whether humans are selfish or evil?',
#   u'Are exocytosis and endocytosis examples of active or passive transport?',
#   u'How i get hair on bald head?',
#   u'What is the ideal life after retirement?',
#   u'What is our stance against Pakistan?',
#   u'What are good websites for escorts?',
#   u'Which one is better polo diesel or grand i10 petrol?',
#   u'Does a black hole have mass?',
#   u'Is Morgan Freeman correct when he says the only way to stop racism, is to stop talking about it?',
#   u'does flab currently offer new employees stock options or rsus',
#   u'how would you review the site wave clues',
#   u'In how many ways can we distribute 10 identical looking pencils to 4 students so that each student gets at least one pencil?',
#   u'How much would it cost to hire Jerry Seinfeld for 1-2 hours?',
#   u'is 7 days too late for rabies vaccine after a possible non bite exposure',
#   u'How many years Britain ruled India?',
#   u'How can I stop being afraid of working?',
#   u'why does red keep the keys in oitnb',
#   u'At what age should someone lose their virginity?',
#   u'How forgetful are you?',
#   u'could stoke secretly be dart maul',
#   u'If I do not monetize YouTube videos & upload copyright content, then are there chances that Google may block my account?',
#   u'would you switch from canon d to leica flux 109',
#   u'What does the Quora website look like to members of Quora moderation?',
#   u'Why nobody answer my questions in Quora?',
#   u'What is the funniest joke you know?',
#   u'I got job offer chelmsfordessex London with 3764 pm pay after tax deduction pals advice tentative monthly expenses for couple saving possible',
#   u'What are stereotypes about the United Kingdom?',
#   u'How do I use Twitter as a business source?',
#   u'how can I transfer money from krill to a papal account',
#   u'Which is the best earphone with deep bass under 1000?',
#   u'are government employees eligible to sukanya samrudi yojana',
#   u"Which is correct - 'Looking forward to speak with you' or 'Look forward to speak with you'?",
#   u'Which are the best engineering fields?',
#   u'How do you make life suit you and stop life from abusing you mentally and emotionally?',
#   u'What is the difference between gross salary and CTC?',
#   u'Which are the prospering towns in Kerala?',
#   u'What is the best way to gain confidence?',
#   u'Does anyone see the relation between Greek gods and Hindu gods?',
#   u'How do I switch from Apple Music to Spotify?',
#   u'Which is the best fixed income fund?',
#   u'What is it like to live in Cologne?',
#   u'Between Robert De Niro and Al Pacino, who is more successful?',
#   u'Why does some people prefer small families.?',
#   u'Do animals kiss?',
#   u'How do you get deleted Instagram chats?',
#   u'How can I stop being addicted to love?',
#   u'What if I hired two private eyes and ordered them to follow each other?',
#   u'How do I find a startup accelerator?',
#   u'How can I check wifi history and access it through android phones?',
#   u'What was the significance of the battle of Somme, and how did this battle compare and contrast to the Battle of Rostov?',
#   u"what is the most creative college admissions essay you've read",
#   u'What would happen if you cover one of your eyes with an eye patch for one year, then take the patch off?',
#   u'Is it possible to pursue many different things in life?',
#   u'Did Ben Affleck shine more than Christian Bale as Batman?',
#   u'Which business is good start up in Hyderabad?',
#   u'How can I stop being so possessive?',
#   u'Who was the wife of Lord Krishna?',
#   u'What is the best combination of courses I can take up along with CA to enhance my career?',
#   u'How do you take a screenshot on a Mac laptop?',
#   u'What is the work of an executive recruiter like?',
#   u"Which psychological need does 'collecting' fulfill?",
#   u'What are some must watch TV shows before you die?',
#   u'How can I become more fluent in Chinese?',
#   u'what are the effects of demonetization of 500 and 1000 rupees notes on real estate sector',
#   u'What is the easiest way to become a billionaire($)?',
#   u'Are there People who are willing to give free lectures or conduct free workshop in India colleges?',
#   u"What's the best way to start learning robotics?",
#   u'Why do people hate Hillary Clinton?',
#   u'why are women who are on their periods are regarded as unclean such that they are prevented in taking an active part in rituals Hinduism',
#   u'If atheism is the lack of belief in gods, what is the term for the belief that there is no god?',
#   u'What is it like to be Jack Dorsey?',
#   u'what are the best quotes lessons of the assassins creed series',
#   u'Do inkjet printers use color ink when printing black and white documents? If so, why?',
#   u'Why is creativity important?',
#   u'If Hillary Clinton could not continue her Presidential campaign how would the Democratic Party choose a new candidate?',
#   u"How headphones work as an Antenna to play FM radio channels on Mobile phones? Why mobile companies doesn't install the same inbuilt Antenna on phones to be able to play FM without the headphones?",
#   u'What are the best career growth technologies for automation engineers apart from automation tools?',
#   u'What are the disadvantages of listing a company in NSE?',
#   u"How many derivatives of an object's position with respect to time have to be continuous?",
#   u'Is the neutron star made up of?',
#   u'I got a 3.8 GPA. Is it enough to get into top universities like Harvard?',
#   u'What is a profitable way to trade binary options?',
#   u'How do I utilize free time to avoid depression?',
#   u'How can I learn computer security?',
#   u'How do I earn from Quora?',
#   u'What is my puk code?',
#   u'How can I find job in Japan?',
#   u'What are some examples of sentences using the word "hysteria"?',
#   u'Will there be another billion dollar lottery Jackpot?',
#   u'How scary is it to drive on the road to Hana given all of the turns?',
#   u'How do I create a new shell in a new terminal using C programming (Linux terminal)?',
#   u'Does cognition affect perception?',
#   u'how trawl is different from cowl tatkal waiting list',
#   u'How can we make the world a better place to live in for the future generations?',
#   u'How many Champions are there in League of Legends?',
#   u'Is drinking 4 liters of water each day unhealthy?',
#   u'Where does the water from the Great Lakes come from, and how does these lakes wildlife compare to Lake Prespa?',
#   u'Do porn stars watch porn?',
#   u"Trump supporters, how do you feel about the way he's walking back his promises?",
#   u"Why are we worried about others' opinions?",
#   u'How do you potty train a 4 months Pitbull?',
#   u'If I jump rope for five minutes, how many calories will I use?',
#   u'Which online test series is best for GATE 2017 in CS stream?',
#   u'What is the best material for understanding algorithmic analysis by a newbie?',
#   u'what is the temperament of a bullmastiffhusky mix',
#   u"There are 8 balls. 7 of them weigh the same. 1 of them has a different weight, (you don't know if it's heavier or lighter). How do you find the odd ball with 2 weighs?",
#   u'in the play a raisin in the sun why do Walter ad beneath argue',
#   u'What are the signs of an ultra smart person playing dumb?',
#   u'If dark energy is created with expansion can infinite of it be created?',
#   u'How do you get a book published?',
#   u'Who is disrupting Bloomberg?',
#   u'Why can flash run so fast?',
#   u'What is the best way to invest $500 legally so that I can get tangible profits over a relatively short period of time, say 6 months?',
#   u'How will the implementation of GST bill impact the lives of common people?',
#   u'How can you recover your Gmail password?',
#   u'How accurately can a mental illness can be diagnosed?',
#   u'Is knee pain in a 20 year old girl normal?',
#   u'What are the qualities of a good leader?',
#   u'What is the difference between bay, gulf and straits?',
#   u'Will Modi win in 2019?',
#   u'how can I open mart store in India is there any franchise for that',
#   u'What are the best YouTube channels to learn medicine?',
#   u'did swami vivekananda ever eat non veg or egg during his journey around the world',
#   u'what will happen if I cancel trawl tickets before the charting is done',
#   u'what exactly is the common core initiative standards and what are the pros and cons',
#   u'How do I choose a journal to publish my paper?',
#   u"What are your New Year's resolutions for 2017?",
#   u'What do you do if you had a bad dream?',
#   u'Why do Slavs squat?',
#   u'How many marks should I score for AIIMS rank 151?',
#   u'In an operating room, when two surgeons of equal experience disagree on a surgical procedure, how is the tie broken?',
#   u'How many months does it take to gain knowledge in developing Android apps from scratch?',
#   u'How do I love my body as a guy?',
#   u'What are the rights of a prisoner?',
#   u'How can I get free gems in Clash of Clans?',
#   u"Why aren't there more apps like Word Lens?",
#   u'my ex girlfriend is suffering from malaria I have a deep urge of visiting her but I have my placements on I have no idea how to be with her what should I do',
#   u'What is the best way to get traffic on your website?',
#   u'how do you feel when someone up votes your answer on quota',
#   u'What are some of the best films and TV shows that feature strong female protagonists?',
#   u'How far would you go for love? Should I wait for the one I love ir move on?',
#   u'How do most people die?',
#   u'Why are most clothes made of polyester now instead of cotton?',
#   u'What is in bone marrow?',
#   u'were there any slave with the name red dice',
#   u'How long does it take for a dead body to float to the surface after drowning ?',
#   u"How do I get over a friend with whom I haven't talked in 3 years but still miss him?",
#   u'When travelling to a new region is it better to immerse yourself in 1\u20132 cities or to see as many cities as you can cram in?',
#   u'How can I make money online with free of cost?',
#   u'Where can I buy best quality customized cupcakes in Gold Coast?',
#   u'How successful was odd even plan?',
#   u'If there will be a war between India and Pakistan who will win?',
#   u'How do you deal with a fear of dying?',
#   u'What would be the estimated cost of repairing the cracked screen of iphone 6?',
#   u"What are the most interesting products and innovations that McDonald's is coming out with in 2016?",
#   u'Is there an end to the universe, and if not, is the universe infinite?',
#   u'what is cpagripcom',
#   u'How much funds should I raise?',
#   u'What Anna Hazare think about PM Modi?',
#   u'What will be the effect of banning 500 and 1000 notes on stock markets in India?',
#   u'How does concentric contractions differ from eccentric contractions?',
#   u'Why did the puppet they used for Yoda in Episode I suck so bad?',
#   u'On what online platforms can I post ads for beer money opportunity?',
#   u'What the meaning of this all life?',
#   u'How should I start small business effectively?',
#   u'How can we acquire a positive morality?',
#   u'Do you need friends?',
#   u'Do I exist?',
#   u'Which are the best Hollywood thriller movies?',
#   u"Should I repeat 2nd year in college, or find a new college? It's a 5 year course.",
#   u'How is petrol or diesel pumped up in a filling station using a motor without igniting any fire?',
#   u'What job possibilities exist for a Bachelors in Homeland Security?',
#   u'Which are the best books to understand calculus?',
#   u'why and how did you break up with her him',
#   u'Can I use Jio SIM in iPhone 5s?',
#   u'What are some unwritten rules in USA?',
#   u'What is the best answer to what you did in two years gap in a job interview?',
#   u'What are the best songs for low voices?',
#   u'Can anyone predict my birth chart?',
#   u'When was the birth of the trigonometric functions?',
#   u'What does this saying mean; "Don\'t trust everything you see even salt looks like sugar"?',
#   u'What do countries do to prevent war?',
#   u'How can I become a billionaire?',
#   u'Why should I learn web design?',
#   u'thaws the best online calenderschedulingbooking system something that allows me to show my availability customers can request to meet me when I accept their request the appointment pops into our calendars reminders are automated',
#   u'How will Indian GDP be affected from banning 500 and 1000 rupees notes?',
#   u'Why does understanding death philosophical?',
#   u'Why are dogs considered omnivores?',
#   u'What it is like to be cheated upon in a relationship?',
#   u'How do I know if someone blocked my texts?',
#   u'What are the most interesting foods you have eaten in any country?',
#   u'What is it like to be a private banker?',
#   u'What is journalism for you?',
#   u'How can one increase concentration?',
#   u'How do I see "sent invitations" on Linkedin if I don\'t have any more pending invitations?',
#   u'What are the pros and cons of the German Shepherd dog?',
#   u'What is the difference between deism and agnosticism?',
#   u'Why do male porn stars masturbate to ejaculate?',
#   u'How much CGPA I require to get an admission for MTech CSE at IIT Madras?',
#   u'Is there a biological reason that people cry when they are emotional?',
#   u"What are 5 facts about the earth's crust?",
#   u'Why does ISRO not use friction stir welding technology?',
#   u'I wish to simulate a fake location for an pap running on my is device how do you fake a gaps location for is without jail breaking as a non coder',
#   u'What would be the best way to quit smoking?',
#   u'Which is the best programing language for tcs?',
#   u'Earthquake resistant homes?',
#   u'Is Kristen Stewart a bad actress?  Why or why not?',
#   u"Why do some Japanese guys try to look feminine? Don't the girls find it gross?",
#   u'What are the five most popular sugar daddy websites?',
#   u'What is the VTU 1st sem exam time table of 2016 (Dec)?',
#   u'What is the best phone to buy below 15k?',
#   u'How do we start a business?',
#   u"thaws the best near death experience you've ever had",
#   u'Why do I keep getting fleas from my dogs?',
#   u'What year did the letter J come?',
#   u'Harvard College Courses: What is general shopping advice for Turkish classes?',
#   u'How do I send message from one Android phone to another Android phone through bluetooth?',
#   u'What are the most important books ever written?',
#   u'What universities does Sigma Designs recruit new grads from? What majors are they looking for?',
#   u'Can we do an M.Phil in India after doing Masters in UK (MA in Psychology)?',
#   u'What universities does Powell Industries recruit new grads from? What majors are they looking for?',
#   u'What are some of the best movie posters you have come across?',
#   u'what are some examples of deuteromycota and how are they formed',
#   u'How racist is too racist?',
#   u'Are there any differences between however and nevertheless?',
#   u'Are Canada Geese really Canadian?',
#   u'how do I find the zeros of the polynomial function mathfxdfrac12x33xmath',
#   u'How do I edit my devices on my Google play account?',
#   u'How can I become a good speaker?',
#   u'How can I write a letter to Mr. Narendra Modi?',
#   u'Who is more electable in a general Presidential election: Donald Trump or Ted Cruz?',
#   u'Why do they name bastards Snow?',
#   u'What do you think about the Bermuda Triangle?',
#   u'Do Mexican girls like black guys?',
#   u'Have you lived in a tiny house?',
#   u'what is a boy girl called when he she is 16 years old 611years old 1114 years old and 1418 years old',
#   u'can you de beak cockerels at 8 months old',
#   u'What should someone do to overcome anxiety?',
#   u'How do we avoid whey in Yogurt?',
#   u'Im in love with my bisexual best friend who is also a guy and has a girlfriend, and I want to tell him. How do I move on?',
#   u'What is the best university in Germany for an MS?',
#   u'How do I maintain my peace of mind?',
#   u'Which car has good build quality in india?',
#   u"Why does massaging one's temples soothe a migraine or headache?",
#   u'Which one is better among KMC Manipal and KMC Mangalore?',
#   u'why are my best friend still ignoring me',
#   u'what are the sensors available in acre liquid z630s android smart phone by using cpuz pap',
#   u'How do I keep motivation to learn a language?',
#   u'What are the top assessment companies in India?',
#   u'What does @ mean as an emoticon?',
#   u'Is a pinkish discharge normal in early pregnancy? What causes it?',
#   u'What are the best ways to properly finger yourself?',
#   u'How do scientists work?',
#   u'How many sponsored candidates are shortlisted for CMC vellore?',
#   u'What is the different between Chinese wedding ceremony and western wedding ceremony?',
#   u'What is the condition of tourism in Pakistan?',
#   u'What is the different between offshore and onshore funds?',
#   u'Why should one hate Shahrukh Khan?',
#   u"what are the best self-help books you've ever read",
#   u'Is Evernote useful?',
#   u'A title for my continuation to The Gift of the Magi?',
#   u'What is a good song to lyric prank your best friend?',
#   u"I argued with my gf that she made friends with the person that hit on her. She said I'm a control freak and she wants her freedom. What should I do?",
#   u'How do I pass a drug test for methamphetamine?',
#   u'How could start with open source development?',
#   u'Why do dreams look so real?',
#   u'Do cricket players really drink tea on a tea break?',
#   u'How can I get entry in MIT?',
#   u"Does a fetus breathe when it's inside a womb?",
#   u'What are movies with incest scenes?',
#   u"What are the signs that a guy has feelings for you or has a crush on you, but doesn't want to show it, so he hides it?",
#   u'According to the International Federation of Robotics, how many robots existed in 2012?',
#   u'Why is Oberon mad at Titania in "A Midsummer Night\'s Dream"?',
#   u'Do you regret your divorce?',
#   u'How much does your DNA change over time? If I were to clone myself 70 years from now, will the clone have the same hair color?',
#   u'Is it right to tell a girl the you have feelings for her?',
#   u'Is Donald Trump taking cocaine, as Howard Dean suggests?',
#   u'Is it true that in order to be part of an elite or just rich and successful, you have to join a secret organisation otherwise no chance at all?',
#   u'Which is more financially beneficial: being in a firm or teaching in an architecture college?',
#   u'How can I see the Comedy Nights with Kapil live show?',
#   u'Why is sandeep maheshwari not on Quora?',
#   u'What is the biggest monster in Monster Hunter?',
#   u'How can I convince people to stop blaspheming against the Holy Spirit?',
#   u"Why can't I stop watching porn?",
#   u'How can I start trusting any one?',
#   u"What's your bucket list?",
#   u'How did you first come across porn?',
#   u'Which car services are available in Normal, IL? How good are they compared to taxis and relative to each other?',
#   u'Why can\u2019t charged molecules pass through the lipid cell membrane?',
#   u'How does it feel to be a spouse of a renowned porn star?',
#   u'What is the best hostel booking affiliate program?',
#   u"How can the drive from Brooklyn to Staten Island be described, and how do these cities' tourist attractions compare to those in Queens?",
#   u'What can I eat every day to be more healthy?',
#   u'How do I make free calls to family members on Airtel Andhra Pradesh?',
#   u'What would Hillary Clinton do now that the election is over?',
#   u'Should I use Vicks Vapor Rub for a stuffy nose?',
#   u'How I start prepare for UGC net English literature latest syllabus?',
#   u'How did early Europeans get protein before the Columbian Exchange?',
#   u'What is the best forum for graphic designers?',
#   u'Is Alex Jones a satirical show?',
#   u'should I learn angularjs 15 instead of angularjs 2 if I dot know typescript',
#   u"Why can't we fall asleep on some days?",
#   u'Which Marvel movies have not included Stan Lee cameos?',
#   u'what are your views on modi governments decision to demonetize 500 and 1000 rupee notes how will this affect economy',
#   u"What does the 10/6 label on the Mad Hatter's hat mean?",
#   u'Who wrote the Kars for Kids jingle?',
#   u'Why is Saltwater Taffy candy imported in Greece?',
#   u'What are the minimum requirements to enter MIT?',
#   u'How do you answer a question on Quora?',
#   u'Israel vs Iran: who would win?',
#   u'When is it too late to learn the piano?',
#   u'What are natural numbers?',
#   u'Is One Plus 3T 4G VoLTE enabled phone?',
#   u'How do I enter a new email ID which I can access to recover my Facebook ID?',
#   u'How we can travel faster than light?',
#   u'What is it like being a firefighter?',
#   u'what are the factors that causes data inconsistency in distributed platform application',
#   u'what are the differences between pock and sexual offences in the pc',
#   u'What is an alternative for the word "is"?',
#   u'What is considered an illegal screen in the NBA?',
#   u'Nothing excites me anymore. How do I regain that excitement?',
#   u'What are the life lessons that Batman teaches us?',
#   u"How do you stop a criminal's attempt to kidnap you so you escape unharmed?",
#   u'How do I sell on Amazon?',
#   u'Daniel Ek: When an we expect Spotify in India?',
#   u'What are the top 10 books one should read in his or her early 20s?',
#   u'Which book should I start with for the GATE preparation?',
#   u'What does the phrase "He who does not love abides in death" exactly mean?',
#   u'what is similar to shared',
#   u'Can you get high if someone touches weed and then you shake their hand and then you eat something with that same hand?',
#   u'Considering the current trend of information technology what is the future of print media?',
#   u'What is the best recipe for chicken pizza?',
#   u'What are some good places to learn mountaineering in India?',
#   u'Do new table tennis balls damage rubbers?',
#   u"My new Xbox one S can't connect to internet during setup. Any solutions?",
#   u'Is it wrong for me to be content with my life?',
#   u'Is gravity only a theory?',
#   u'How could I become a fighter pilot when I have less than the required eyesight?',
#   u'Operation executive salary in Infosys?',
#   u'Have cavemen been scientifically tested?',
#   u'Can climate change be reversed?',
#   u'How should ask my crush for her number?',
#   u'Why do I believe that gravitation force exist?',
#   u'Did Mahabharata really happen?',
#   u'Can Congress stop Presidents from starting a major war?',
#   u'Is it safe to lose 25 pounds in 1 month?',
#   u'what are some cute shounen AI series',
#   u'Why are police lights red and blue?',
#   u'How do I post a question that was marked as needing improvement?',
#   u'Who owns nature?',
#   u'how can I install obbdata file on an android',
#   u'What is garbage value? And Why do we get garbage value in c?',
#   u'How do I prepare for software interviews?',
#   u'Does Rahul Gandhi have any chance to become next PM of India after Modi?',
#   u'Is noon 12 am or 12 pm?',
#   u'What is the difference between a comet and an asteroid?',
#   u'Is chocolate milk good for you?',
#   u'How should I study',
#   u'Which country is best for higher education and work?',
#   u'What is the painting on this image?',
#   u'Which are the major highways in California and how are they compared to the major highways in Tennessee?',
#   u"What's beyond our Universe?",
#   u'Is growing of hair a physical or a chemical change?',
#   u'What is the difference between culture and history?',
#   u'What does it mean when a guy says I like you?',
#   u'What makes a programmer "good?"',
#   u'What will most likely cause World War III?',
#   u'Is civil war likely after the US presidential election?',
#   u'Which European country is the best for asylum seekers?',
#   u'Where and how do the crop circles get generated?',
#   u'Will baking soda help pass a urine test?',
#   u'What is Zika virus and how is it transmitted?',
#   u'What is the best way to learn algebra by yourself?',
#   u'How does it feel to retake a class in college?',
#   u'does goggle display network require any site to have it so on page and off page optimized first before they can proceed with gin is this possible',
#   u'How hard is it to fake appearing "spiritual" in a Christian community?',
#   u'What is an actinomorphic flower?',
#   u'What is the best place for sex?',
#   u'Do people with anemia die younger?',
#   u'How do you feel about the new MacBook Pro, late 2016?',
#   u'Does covering your head while sleeping cause brain damage?',
#   u'What are the major differences between Chinese culture and western cultures?',
#   u'What are scraping techniques?',
#   u'I am 29y old I have diabetic type 2 recently my sugar level was increased to 150 fasting I do exercise and eat whole grains why this happening',
#   u'Is it healthy to eat egg whites every day?',
#   u'what words rank the highest on dictionarycoms difficulty index',
#   u"Why can't I feel remorse or empathy at all?",
#   u'How many minutes of cardio a day should I do?',
#   u'Why is my dog biting me?',
#   u'How can I treat a severe foot sprain?',
#   u'How can a severe crick in the neck be treated?',
#   u'What are the best places to recommend foreigners to visit in Nepal?',
#   u'who do I activate the doc of sky rim in a laptop vie got it working on my computer after doing the command lines but did the same on laptop to no use',
#   u'How should I prepare for HSBC GLT placement tests?',
#   u'did any Indian writers authors ever use a pen name',
#   u'How do I register institute providing training in various programming languages for vocational courses as it will exempt it from the service tax?',
#   u'How imminent is world war III?',
#   u'How do you write a song?',
#   u"What could be Narendra Modi's next move after demonetization?",
#   u"If you have me, you want to share me. If you share me, you haven't got me. What am I?",
#   u"what is an interesting fact that you know and I dot but shouldn't",
#   u'What is the problem with controlled fusion?',
#   u'Where do I find 3ds emulator for android?',
#   u'I want to start my clothes boutique in India, from where can I buy cheap wholesale clothes?',
#   u'How can I become a true computer science engineer?',
#   u'Is it necessary to unlock bootloader before rooting Android phones?',
#   u'What is bss engineer?',
#   u'Why do I get punished by Quora moderators when I put Israel and Judaism in a negative light?',
#   u'What can you do in lucid dreams?',
#   u'What does it feel like to be beautiful?',
#   u'Is it possible to do CA after 12th Science?',
#   u'How can I hack someones whatsapp account?',
#   u'What is it like to study math at UCLA?',
#   u'What is the best lesson in life?',
#   u'What are some Interesting mobile apps?',
#   u"How will Trump's presidency affect Indian students who are planning to do a PhD in the US?",
#   u'What are the various Batman movies in the series? (In order)',
#   u'What are the best daily life hacks one can use to make his life easy?',
#   u'How much weight will I lose by not eating for a week?',
#   u'What is your favourite anime character and why?',
#   u'How do ATM machines work internally?',
#   u'How many Mechanical Engineers graduate from India per year?',
#   u'How do I start a successful private equity firm?',
#   u'What are most underrated date activities?',
#   u'What are some common facts every mechanical engineer should know?',
#   u'What can be the medium budget to visit best places in Kerala for three members (2-3 days)?',
#   u'Why is Quora Digest filled with questions about Google, IQ, and China?',
#   u'How would you destroy the world?',
#   u'How can I earn money from YouTube?',
#   u'What are the differences between particles and molecules?',
#   u'On Facebook, how can I add mutual friends?',
#   u'What is Russian president Vladmir Putin like as a person, to his closest friends and family?',
#   u'How do I start writing again?',
#   u'If time started because of the big bang happening then how could the big bang start because there was no time for the big bang to start?',
#   u'How does it feel to be in a relationship than being single and how does our life changes when we are in a relationship?',
#   u'How can I start civil service exam preparation from scratch?',
#   u'What are the non-invasive blood glucose monitoring systems abroad?',
#   u'What is the difference in pleasure between masturbation and sex?',
#   u'What does "the more things change the more they stay the same" mean?',
#   u'How do I start a solar energy business in egypt?',
#   u'can my pc with specks 2 GB ddr2 ram inlet core duo 35 GHz nvidia enforce GT 610 3gb ddr3 run assassins creed syndicate and tag v',
#   u'Do you have any psychic abilities?',
#   u'How do I manage time for studies?',
#   u'What is the academic calendar at XLRI?',
#   u'what is your take on urjit petal as the new rib governor',
#   u'Why do you want to be to president?',
#   u"Why India does not have friendly relations with it's neighbouring countries?",
#   u'Do Trump voters care that he has reneged all his campaign promises?',
#   u'Can I learn while sleeping? If so, how?',
#   u'Can you play Asian Playstation 4 games on a European Playstation?',
#   u'How do I stop being addicted to porn?',
#   u"Why did British engineering and manufacturing skills decline so dramatically in the 60s, 70s and 80s, especially when compared with Germany's?",
#   u'How do I work with machine learning researchers after graduation?',
#   u'What is the future for iOS Developers?',
#   u'What is the meaning of life? Whats our purpose on Earth?',
#   u'How do I be a boyfriend?',
#   u'How is time travel possible?',
#   u'How can one get a fuller face?',
#   u'Is it too late for me at the age of 25 thinking to start a career in photography?',
#   u'What\u2019s the best time to have sex?',
#   u'Can we weld steel and aluminum together?',
#   u'which you tube video has the highest like dislike ratio',
#   u'What is solution to Kashmir issue?',
#   u'If you dug a hole through the earth, and came out the other side what would happen?',
#   u'Can we create free energy?',
#   u'What should I do for Web design?',
#   u"thaws the funniest highbrow joke you've ever heard",
#   u'How do I find the phenotypic ratio?',
#   u'Why does Saturn benefit a house it sits in slowly?',
#   u'Who is the most academically qualified Bollywood celebrity?',
#   u'Is there a difference in quality between wired and wireless headphones? If so, why?',
#   u'What are some movies that everyone needs to watch at least once in life?',
#   u'Can World War 3 ever take place?',
#   u'How can eating prunes help during a constipation?',
#   u'you have given all statement as correct in unclad question in case prelim 2016 while many coaching have taken end statement as wrong',
#   u'What would be today\u2019s technology had we never realized the value of binary numbers and harnessed it to produce digital technology?',
#   u'What is the best way to invest in oil and natural gas?',
#   u'is arnab go swami prober',
#   u'what are some good sources for learning nugget',
#   u'How would do you describe a person with lots of interests?',
#   u'Is it possible to turn off indicator light on a dahua camera?',
#   u'Why is Barack Obama so important for the world?',
#   u'What is the reason Pakistan supports terrorism?',
#   u'how do I can stop hairball',
#   u'In your opinion, what is the best classical song of all time?',
#   u'What are some unusual aspects about politics and government in Hungary?',
#   u'What is the aim?',
#   u'How should I respond to my boss who fired me via email?',
#   u'What are cheap and budget stay options in North Goa?',
#   u'Is there any other website similar to Quora?',
#   u'What are the conditions in European refugee camps?',
#   u'what is the opposite of home bird',
#   u'How do you know that your fiance loves you?',
#   u'Can somebody explain to me how to do this problem with steps?',
#   u'How do I develop my presence of mind?',
#   u'Mathematical Fallacies: What is wrong in this proof that 2+2 = 5?',
#   u'will it help civil score if I pay off my written off amount',
#   u'Should the Hobbit be considered a canonical Tolkien work?',
#   u'What do Japanese think about Malaysian?',
#   u'Is the Har Ki Dun trek easy?',
#   u'what are the good websites to learn c programming for beginner',
#   u"Will the Supreme Court's decision of playing the National Anthem before movie screenings affect your patriotism?",
#   u'If the United States has a female president, will her husband be called the first gentleman? What will Bill Clinton be called if Hillary is elected?',
#   u'how can I get moocelearning through online web and video courses related to film making production developed by Indian professors',
#   u'Mobile Number Portability finally will start on May 3. Do network providers really agree to this?',
#   u'Why do people hate twilight saga?',
#   u'Do you believe imperialism left a positive or negative legacy in the Indian subcontinent and in Africa?',
#   u'Why is C the best programming language?',
#   u'How can I improve my spoken English ability?',
#   u'How can I have gay sex?',
#   u"I'm transferring to a school with a US curriculum (taking the IBDP) from a Philippine school w/ a percent average grading system. How do I get my GPA?",
#   u'How do I make money with YouTube?',
#   u'How do I find love in life?',
#   u'Which option is better to reduce weight, swimming or gym?',
#   u'Is there any way to get rid of gynecomastia?',
#   u'which payment gateway in Saudi that using to collect and pay money from to multiple',
#   u'Are there any scientific reasons behind Hindu temples?',
#   u'Is (male) circumcision required in Islam?',
#   u'Where can I get super high quality photos for any photo booth services in Sydney?',
#   u'How can I find out whom I sent a friend request to on Instagram?',
#   u'How can I control on my anger?',
#   u'What are genders?',
#   u'How do I get off Quora?',
#   u'How long can raw and cooked sausage last refrigerated?',
#   u'What are the best available smartphones gadgets?',
#   u'How does it feel to be a closeted gay in India?',
#   u'Can we switch roles at Amazon?',
#   u'What happens if dictatorship is continuing in the present days?',
#   u'What makes a great cup of coffee great?',
#   u'Is the US election rigged?',
#   u'why hast gale laakmann mcdowellcareercup created a moo or a coding boot camp',
#   u'What is fermentation? What are some products of fermentation?',
#   u'what do you think about my short film colorshift',
#   u'Should there be a war between India and Pakistan for Kashmir?',
#   u'What is the best way to get you food stamp card?',
#   u'What are some real world example of encapsulation and abstraction and how are they different, yet related?',
#   u'What are ways to deal with fabricate security and insurance of android application?',
#   u'What is the best accordion for beginners to learn on?',
#   u'Role of junior leaders in Indian army?',
#   u"What's your opinion about the decision on removal of 500 and 1000 rupees currency notes?",
#   u'What are some of the most mind-blowing facts about Bengaluru?',
#   u'If both the parents have blood group B+, can the child have A+?',
#   u'Which book is best for Neet chemistry?',
#   u'What is the essence of enlightenment?',
#   u'Why are so many questions posted to Quora that are so easily answered by using Google?',
#   u'How should I answer if an interviewer asks me to sell a pen or any other product as I am pursuing a MBA?',
#   u'What are some great side dishes for a minestrone soup?',
#   u'How much is the maximum gold you can take when flying from India to USA?',
#   u'If my reservation status is RAC, does it mean the seat has been confirmed?',
#   u'How does a new website protect its design and user interface from copycats?',
#   u'How can I improve my skills?',
#   u'Is it possible to use SPI between AVR and Raspberry pi?',
#   u'Which are the best movies of 2016?',
#   u'What would be effect of 500 and 1000 Rs notes ban?',
#   u'What are some of the best photos?',
#   u'Why students run away from home?',
#   u'In C++, what are access modifiers?',
#   u'Can you analyze history, or is it unscientific?',
#   u'What are some interesting theories about life after death?',
#   u'Do I need to get a tetanus shot again?',
#   u'How light bend with gravity?',
#   u'What does it mean to hike up your skirt?',
#   u'How many new cars are sold by Maserati in the US each year?',
#   u"How do you send a private message to someone you're following on Quora?",
#   u'How do you train a white Pitbull with brown spots?',
#   u'What is the difference between a turkey and a chicken?',
#   u'What are some of the most surreal questions asked on Quora?',
#   u'What is the difference between IT and computer science engineering?',
#   u'When will the best time for having sex?',
#   u'How can I consult a good free online astrologer?',
#   u"Why we don't feel sympathy towards everyone?",
#   u'Why do brothers hate sisters?',
#   u'What is the best site for downloading Kannada films in torrent form?',
#   u'What are some of the most gruesome causes of death?',
#   u'What is latency in telecom?',
#   u'Is senior residency at Hindu Rao Hospital teaching experience?',
#   u'What behavioral adaptations do pandas have?',
#   u'Is Textile Engineering Good?',
#   u'What is the fastest production car?',
#   u'How magnets are made?',
#   u'thaws the street value of a332',
#   u'What are the qualifications for being an FBI or CIA agent?',
#   u'What is the best operating system for the PC in 2014?',
#   u'Why are major Indian TV channels absent in northeast?',
#   u'Hypothetical scenario: Our actual credit card system & banking never existed before. How would you implement a digital currency on the Internet today?',
#   u'How does Quora quickly mark questions as needing improvement?',
#   u'How will I contact a good hacker?',
#   u'What are the best horror novel in 2016?',
#   u'What is the most beautiful thing that you have ever seen?',
#   u'What are the most important things for living a good life?',
#   u'What is the meaning and purpose to life?',
#   u'What should I do when my friends betray me?',
#   u"I'm 15 year old my height is 5 feet 7 inches and my weight is 50 kg what should I do to gain weight?",
#   u'Why is Saltwater taffy candy imported in China?',
#   u'Is there a different price over the Internet than in person when trying to book a room in Mexico City from the US?',
#   u'why did venuetastic fail',
#   u'Which were some of the most amazing responses you have got with Cortana, Siri or Amazon Echo?',
#   u'What is most important in life - money or values?',
#   u'Who are the best hackers in India?',
#   u'Should the Indian education system be changed?',
#   u'What are the multiple uses of hollow columns?',
#   u'Which are some commonly mispronounced words?',
#   u'Why is it that every teen girl has a crush on her mathematics teacher? Is it the intelligence or their behavior?',
#   u'Is it too late to go to medical school and become a doctor?',
#   u'where can I buy best quality commercial innerspring sofa bed in chats wood west',
#   u'if you screen shot someone instagram video will they get notified that you screens hotted it',
#   u'What government exams, other than the GATE, can final year computer science students give?',
#   u'What sentences use all 26 letters without any repeats?',
#   u'what is the effect of hypo density of white matter in parietal lobe of brain',
#   u'What is your job and your salary? Are you satisfied with your current job?',
#   u'Psychopaths: Do you find babies cute?',
#   u'What is the opera song with a choir used for horror movies?',
#   u'Would a woman in the Catholic Church be shunned or ostracized for having a sexual relationship with a priest?',
# ...
#             8.49889000e-01,  -5.13816100e-01,   1.20118100e+00,
#            -9.68762000e-01,  -4.33964900e+00,  -1.47579000e-01,
#             2.15927940e+00,  -3.34891000e+00,  -1.58586000e+00,
#             7.99377000e-01,   2.85107000e+00,  -1.92963000e+00,
#            -1.90109730e+00,  -8.85767000e+00,  -1.64555000e-01,
#            -1.27554000e+00,   2.09260900e+00,   1.00296600e+01,
#            -2.51534100e+00,  -2.21609200e+01,   1.59437500e+00,
#            -1.70010200e+00,   1.43521000e+01,   4.04474100e+00,
#            -1.82895500e+00,   6.63247000e+00,  -3.81108700e+00,
#            -3.17975700e-01,   7.17501800e+00,   1.16042100e+00,
#             3.82522000e+00,   4.65352400e+00,  -1.03003700e+00,
#            -3.80972000e+00,  -1.46777000e-01,  -6.57937700e+00,
#            -2.17618390e+00,  -3.00245300e+00,   7.58990000e-01,
#            -5.36212000e-01,   5.57598000e-01,  -1.13144700e+00,
#            -6.57979000e+00,   1.50988000e-01,   6.36857000e+00,
#             1.46122200e+00,  -4.78145600e+00,   5.57246800e-01,
#            -1.22542300e+01,  -2.23845700e+00,   3.70158200e+00,
#             4.89370000e-03,  -2.07617700e+00,  -3.51752000e+00,
#            -2.09960000e-01,  -2.53038000e-01,  -9.19659000e-01,
#            -2.35655490e+00,  -2.92213500e+00,  -7.81762000e-01,
#            -6.95222800e-01,  -2.38691600e+00,   3.22052000e+00,
#             1.31721000e+00]]),
#   array([[  0.211486  ,   1.67622   ,   3.7017    ,  -3.496763  ,
#            -3.724217  ,   3.299049  ,   1.0954878 ,   4.90465   ,
#            -0.379933  ,  -1.504059  ,   2.128977  ,   2.31807   ,
#             3.730414  ,   4.195348  ,   0.7644197 ,  -3.362404  ,
print 'tokenizing question 1'
tok_question1 = pool.map(tokenizer_worker, quora.question1)
print 'done'

print 'saving tokenization...'
with open('data/tokenized_question1_%s.pkl' % time.time(), 'w') as f:
    pickle.dump(tok_question1, f)


print 'tokenizing question 2'
tok_question2 = pool.map(tokenizer_worker, quora.question2)
print 'done'

print 'saving tokenization...'
with open('data/tokenized_question2_%s.pkl' % time.time(), 'w') as f:
    pickle.dump(tok_question2, f)


pool.close()
# Out:
# 8
# tokenizing question 1
# done
# saving tokenization...
# tokenizing question 2
# done
# saving tokenization...
# time: 44min 53s

# %%
# munge tokenizations
wv1 = zip(*tok_question1)[1] 
emb_q1 = np.vstack(wv1)
print emb_q1.shape

wv2 = zip(*tok_question2)[1] 
emb_q2 = np.vstack(wv2)
print emb_q2.shape

emb_q1q2 = np.hstack((emb_q1, emb_q2)) 
print emb_q1q2.shape
# Out:
# (404351, 100)
# (404351, 100)
# time: 4.4 s

# %%
# save tokenization as numpy array
np.savetxt("data/embedding_q1q2_%s.csv" % time.time(), emb_q1q2, delimiter=",")
# Out:
# time: 1min 14s

# %%
# tokenizer_worker = TokenizerWorker(tokenizer, gl_vocab_index, gl, replacer)
# quora.question2.map(tokenizer_worker)

# %%
with open('data/tokenized_question1_1486096656.54.pkl') as f:
    tok_question1 = pickle.load(f)
with open('data/tokenized_question2_1486103937.45.pkl') as f:
    tok_question2 = pickle.load(f)
# Out:
# time: 2min 14s

# %%
from sklearn.cross_validation import train_test_split
q1_train, q2_train, q1_test, q2_test, ytrain, ytest = train_test_split(tok_question1, tok_question2, quora.is_duplicate.values)
# Out:
# time: 348 ms

# %%
train_sim = [cosine_similarity(q1_train[i][1], q2_train[i][1])[0,0] for i in range(10000)]
ytrain = ytrain[:10000]
# Out:
# time: 1.46 s

# %%
train_sim = np.array(train_sim)
# Out:
# time: 1.67 ms

# %%
plt.hist(train_sim[np.where(ytrain==1)[0]], normed=True, alpha=0.3, label='positive', bins=100)
plt.hist(train_sim[np.where(ytrain==0)[0]], normed=True, alpha=0.3, label='negative', bins=100)
plt.legend();
# Out:
# time: 761 ms

# %%
thres = 0.85
pred = train_sim > thres
p = sum(np.logical_and(pred==1, ytrain==1)) / float(sum(pred))
r = sum(np.logical_and(pred==1, ytrain==1)) / float(sum(ytrain==1))
print p, r, 2*p*r/(p+r)
# Out:
# 0.377379983727 0.625235912645 0.470671808403
# time: 51.7 ms

# %%
# validation that word vectors are close
from sklearn.metrics.pairwise import cosine_similarity
for i in range(100):
    print tok_question2[i][0], tok_question1[i][0]
    print cosine_similarity(tok_question2[i][1], tok_question1[i][1])[0,0], quora.is_duplicate.values[i]
# Out:
# What is the step by step guide to invest in share market? What is the step by step guide to invest in share market in india?
# 0.994985474829 0
# What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) diamond back? What is the story of Kohinoor (Koh-i-Noor) Diamond?
# 0.890191977161 0
# How can Internet speed be increased by hacking through DNS? How can I increase the speed of my internet connection while using a VPN?
# 0.961039587557 0
# find the remainder when math2324math is divided by 2423 Why am I mentally very lonely? How can I solve it?
# 0.817308079324 0
# Which fish would survive in salt water? which one dissolve in water quickly sugar salt methane and carbon id oxide
# 0.919948337727 0
# I'm a triple Capricorn (Sun, Moon and ascendant in Capricorn) What does this say about me? astrology I am a Capricorn sun cap moon and cap rising what does that say about me
# 0.964879978034 1
# what keeps children active and far from phone and video games Should I buy tiago?
# 0.781134639535 0
# What should I do to be a great geologist? How can I be a good geologist?
# 0.986442144197 1
# When do you use "&" instead of "and"? When do you use シ instead of し?
# 0.997254960514 0
# how do I hack Motorola dcx3400 for free Internet Motorola company can I hack my charter Motorola dcx3400
# 0.922937048051 0
# What are some of the things technicians can tell about the durability and reliability of Laptops and its components? method to find separation of slits using Fresnel bi prism
# 0.900472892674 0
# How can I see all my Youtube comments? How do I read and find my YouTube comments?
# 0.992408958166 1
# How can you make physics easy to learn? What can make Physics easy to learn?
# 0.99594058549 1
# What was your first sexual experience? What was your first sexual experience like?
# 0.994850634373 1
# What are the laws to change your status from a student visa to a green card in the US? How do they compare to the immigration laws in Japan? What are the laws to change your status from a student visa to a green card in the US, how do they compare to the immigration laws in Canada?
# 0.999115509294 0
# How will a Trump presidency affect the students presently in US or planning to study in US? What would a Trump presidency mean for current international master’s students on an F1 visa?
# 0.955003324554 1
# What does manipulation means? What does manipulation mean?
# 0.99257258235 1
# How do guys feel after rejecting a girl? Why do girls want to be friends with the guy they reject?
# 0.970055596134 0
# Why do people ask Quora questions which can be answered easily by Google? Why are so many Quora users posting questions that are readily answered on Google?
# 0.974665435745 1
# Which is the best digital marketing institute in Pune? Which is the best digital marketing institution in banglore?
# 0.984616985529 0
# Why are rockets and boosters painted white? Why do rockets look white?
# 0.92818095949 1
# What can I do to avoid being jealous of someone? What's causing someone to be jealous?
# 0.963083442376 0
# Which question should I ask on Quora? What are the questions should not ask on Quora?
# 0.984931499981 0
# Where can I find a conversion chart for CC to horsepower? How much is 30 kV in HP?
# 0.931097971492 0
# How many times a day do a clock’s hands overlap? What does it mean that every time I look at the clock the numbers are the same?
# 0.978525052896 0
# What are some tips on making it through the job interview process at Foundation Medicine? What are some tips on making it through the job interview process at Medicines?
# 0.992619090255 0
# What is the web application framework? What is web application?
# 0.974344881031 0
# How do sports contribute to the society? Does society place too much importance on sports?
# 0.970908772602 0
# What is best way to ask for money online? What is best way to make money online?
# 0.99629977145 0
# how one should know that he she completely prepare for Ca final exam How should I prepare for CA final law?
# 0.979193335005 1
# What's one thing you do despite knowing better? What's one thing you would like to do better?
# 0.984463873378 0
# How can I keep my nose from getting stuffy at night? What are some special cares for someone with a nose that gets stuffy during the night?
# 0.953752576898 1
# What Game of Thrones villain would you most like to be at the mercy of? What Game of Thrones villain would be the most likely to give you mercy?
# 0.99107200303 1
# How is the average speed of gas molecules determined? Does the United States government still blacklist (employment, etc.) some United States citizens because their political views?
# 0.841740062356 0
# What is the best travel website? What is the best travel website in spain?
# 0.980858722085 0
# Has there been a gun control initiative to take away guns people already own? Why do some people think Obama will try to take their guns away?
# 0.948199641544 0
# I am a 19 year old guy. How can I become a billionaire in the next 10 years? mi a 19yearold how can I improve my skills or what should I do to become an entrepreneur in the next few years
# 0.956708464533 0
# My girlfriend said that we should end this because she is confused about her feelings for me. I wished her well and disconnected. Should I call her and ask her if she wants to get back together? When a girlfriend asks her boyfriend "Why did you choose me? What makes you want to be with me?", what should one reply to her?
# 0.988787220755 0
# How do I prepare for civil service? How do we prepare for UPSC?
# 0.962474213361 1
# why did aircraft stop using variable sweep wings like those on an f14 What is the stall speed and AOA of an f-14 with wings fully swept back?
# 0.946981025146 0
# Will squats make my legs thicker? Why do Slavs squat?
# 0.743634717249 0
# When can I expect Cognizant confirmation mail? When can I expect my Cognizant confirmation mail?
# 0.993072620004 0
# Can I make 30,000 a month by day trading? Can I make 50,000 a month by day trading?
# 0.997699187287 0
# Is being bored good for a kid? Is being a good kid and not being a rebel worth it in the long run?
# 0.954503140776 0
# What universities does B&G Foods recruit new grads from? What majors are they looking for? what universities does rexnord recruit new drags from what majors are they looking for
# 0.984233048497 0
# How can we increase our number of Instagram followers? What is the quickest way to increase Instagram followers?
# 0.958920883988 0
# Does Quora have a character limit for profile descriptions? How did Darth Vader fought Darth Maul in Star Wars Legends?
# 0.619763921998 0
# Who is affected more by a breakup, the boy or the girl? What are the stages of breaking up between couple? I mean, what happens after the breaking up emotionally whether its a male or female?
# 0.965970631942 0
# What are some of the products made from crude oil? What are some examples of products that can be make from crude oil?
# 0.985284951474 1
# How to make friends ? How do I make friends.
# 0.972315710588 1
# How is career launcher online program for RBI Grade B? Is Career Launcher good for RBI Grade B preparation?
# 0.965330037422 1
# How can you play a Blu Ray DVD on a regular DVD player? Will a Blu Ray play on a regular DVD player? If so, how?
# 0.987166603553 1
# Aerodynamically what happens when propellor rotates? Nd she is always sad?
# 0.756726435791 0
# what is the most delicious dish you've ever eaten and why what is the best most memorable thing you've ever eaten and why
# 0.973452421468 1
# Why can't I do my homework? How GST affects the CAs and tax officers?
# 0.6727422549 0
# Do you apply for programs like RSI when you're a rising senior? How difficult is it get into RSI?
# 0.950180863242 0
# Is my boyfriend lying about his true feelings for his friend and is he secretly attracted to her? who is is rail friend
# 0.932553404329 0
# What are some of the best rap songs? What are some good rap songs to dance to?
# 0.984301187794 0
# I can't remember my Gmail password or my recovery email. How can I recover my e-mail? I was suddenly logged off Gmail. I can't remember my Gmail password and just realized the recovery email is no longer alive. What can I do?
# 0.966047510338 1
# How do I learn french genders? What are the best ways to learn French?
# 0.927471697686 0
# is kick ass torrents trustworthy how do I download content from a kick ass torrent without registration
# 0.697587342378 0
# What causes a dark ring around the iris? How should it be treated? Is it normal to have a dark ring around the iris of my eye?
# 0.983022484106 0
# How bad is the new book by J.K Rowling? How is the new Harry Potter book 'Harry Potter and the Cursed Child'?
# 0.931626565023 1
# Why do I always get depressed in the evening? Why do I always get depressed?
# 0.964120648383 0
# Where do I find a U.S. family office database? Where can I find a European family office database?
# 0.985269403452 0
# How do I learn a computer language like java? What is Java programming? How To Learn Java Programming Language ?
# 0.940049379594 1
# What is the most important book you have ever read? What is the best book ever made?
# 0.979191685524 1
# Is it possible to store the energy of lightning? Can we ever store energy produced in lightning?
# 0.963714651134 1
# What is performance testing? What is your review of Performance Testing?
# 0.975528682708 0
# Are there any people who genuinely enjoy salad with no dressing? At what cost does so much privacy as in Germany come? What else is lost to gain so much privacy?
# 0.897316310174 0
# What are the different types of immunity in our body? What are the types of immunity?
# 0.989700549344 0
# What is narcissistic personality disorder? What is a narcissistic personality disorder?
# 0.985098966262 1
# How can I learn to speak English fluently? How I can speak English fluently?
# 0.99215355177 1
# What is the quickbooks customer support phone number USA? How helpful is QuickBooks' auto data recovery support phone number to recover your corrupted data files?
# 0.926093654361 1
# Who is the richest gambler of all time and how can I reach his level as a gambler? Who is the richest gambler of all time and how can I reach his level?
# 0.996430638575 1
# Do bullets travel faster than the speed of sound when shot from a gun? If not, is it possible? If they do, what gun and how much devastation occurs? If I fire a bullet backward from an aircraft going faster than the bullet; will the bullet be going backwards?
# 0.973238322532 0
# Is breast cancer preventable? How do I prevent breast cancer?
# 0.809784428216 0
# How can I know who logged in to my Gmail account? (by telling his IP address or device name)? How do I log out of my Gmail account on my friend's phone?
# 0.976203761786 0
# What are some different ways to make money online, excluding selling things? How can I make money through the Internet?
# 0.960015982125 0
# What's the purpose of life? What is life actually about? What is purpose of life?
# 0.986153701412 1
# why India does not apply the burmarohingya model to deport illegal Bangladeshi When will the BJP government strip all the Muslims and the Christians of the Indian citizenship and put them on boats like the Rohingya's of Burma?
# 0.882667798176 0
# How important is it to be the first person to wish someone a happy birthday? What is the right etiquette for wishing a Jehovah Witness happy birthday?
# 0.966966359414 0
# I want to make a travel commercial clip video d for India and new Zealand how much will it cost If someone wants to open a commercial FM radio station in any city of India, how much does it cost and what is the procedure?
# 0.971358614712 0
# Why do technical employees despise sales people so much? Why do Swiss despise Asians?
# 0.857738917379 0
# What are some high paying jobs for a fresher with an M.Tech in biotechnology? What are some of the high salary income jobs in the field of biotechnology?
# 0.965798961111 1
# Can height increase after 25? How can I increase my height after 21 also?
# 0.935212017774 1
# What were the major effects of the cambodia earthquake, and how do these effects compare to the Valparaiso earthquake in 1822? what were the major effects of the Cambodia earthquake and how do these effects compare to the kamchatca earthquakes in 1952
# 0.993428026991 1
# What's the difference between honest and sincere? What is the difference between sincerity and fairness?
# 0.950451884499 0
# Which is the best gaming laptop under Rs 60000? Which is the best gaming laptop under 60k INR?
# 0.968829524105 1
# What is your review of The Next Warrior: Proving Grounds - Part 5? What is your review of The Next Warrior: Proving Grounds - Part 9?
# 0.99963809363 0
# Which book should I choose for reference for physics and chemistry (class 11, CBSE board)? What is the best reference book for physics class 11th?
# 0.951816821326 0
# national institute of technology karnataka nit surathkal to the graduating batch what lessons would you want to give to your juniors before you leave national institute of technology kurukshetra how is the social life at nit surathkal
# 0.907119091504 0
# What is the best romantic movie you have ever seen? What are some of the best romantic movies in English?
# 0.962691608173 1
# What causes nightmares that seem real? What causes a nightmare?
# 0.938754931762 1
# What are some of the major influences of abstract expressionism? What is abstract expressionism in painting?
# 0.900599866884 0
# How do 3D printing work? How does 3D printing work?
# 0.991765064144 1
# Who are some notable folks who attended Caltech? What was it like to attend Caltech with Jeremy Ehrhardt?
# 0.889838536618 0
# What is a Horcrux? Why did harry become a horcrux?
# 0.928219969547 0
# What are the general requirement to become a Product Manager or a Program Manager in a product based software company? What are the best associate product manager (APM) programs that someone in their early 20s can join to learn product management and have a rewarding career in the company?
# 0.967579885949 0
# How could I get Skype to work on an android 4.1.1 phone? why is the number for Skye at 18554253768 always busy
# 0.912360087153 0
# time: 28.9 ms

# %%
# string featurizations (shingling, jacquard), character deeplearning byte-pair encoding, snli
# specific first architecture: lstm with attention

# %% [markdown]
# ## conll format

# %%
from nltk.tokenize import word_tokenize
from enchant.checker import SpellChecker


EOS_CHAR = 'zzzz'
# Out:
# time: 1.82 ms

# %%
print 'loading data...'
quora = pd.read_csv('data/quora_duplicate_questions.tsv', sep='\t', encoding='utf-8')
print quora.shape
quora.head(2)
# Out:
# loading data...
# (404351, 6)
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# time: 1.2 s

# %%
# replacer = SpellingReplacer()
np.random.seed(0)

def tokenize_quora_row(row, file_dict):
    # tokenize
    try:
        q1_tok = word_tokenize(row['question1'])
        q2_tok = word_tokenize(row['question2'])
        conll_entry_a = '\n'.join(q1_tok) + '\n\n'
        conll_entry_a = conll_entry_a.encode('utf-8')
        conll_entry_b = '\n'.join(q2_tok) + '\n\n'
        conll_entry_b = conll_entry_b.encode('utf-8')        
        label_entry = str(row['is_duplicate'])+'\n'
    except:  # encoding errors, not str, etc.
        return
    
    # split train/dev/test
    x = np.random.random()
    if x < .6:
        k = 'train'
    elif x < .8:
        k = 'dev'
    else: 
        k = 'test'
    
    # write
    fa, fb, flab = file_dict[k]['fa'], file_dict[k]['fb'], file_dict[k]['flab']
    fa.write(conll_entry_a)
    fb.write(conll_entry_b)
    flab.write(label_entry)
# Out:
# time: 17.1 ms

# %%
# tokenize conll
with open('data/dat_train_a.conll', 'w') as trainaf:
    with open('data/dat_train_b.conll', 'w') as trainbf:
        with open('data/labels_train.conll', 'w') as trainlabelf:
            with open('data/dat_dev_a.conll', 'w') as devaf:
                with open('data/dat_dev_b.conll', 'w') as devbf:
                    with open('data/labels_dev.conll', 'w') as devlabelf:        
                        with open('data/dat_test_a.conll', 'w') as testaf:
                            with open('data/dat_test_b.conll', 'w') as testbf:
                                with open('data/labels_test.conll', 'w') as testlabelf:
                                    file_dict = {
                                        'train': {'fa': trainaf, 'fb': trainbf, 'flab': trainlabelf},
                                        'dev': {'fa': devaf, 'fb': devbf, 'flab': devlabelf},
                                        'test': {'fa': testaf, 'fb': testbf, 'flab': testlabelf}
                                    }
                                    tok_conll = quora.apply(lambda x: tokenize_quora_row(x, file_dict), axis=1)
# Out:
# time: 2min 40s

# %%
# tokenize conll small
with open('data/sm_dat_train_a.conll', 'w') as trainaf:
    with open('data/sm_dat_train_b.conll', 'w') as trainbf:
        with open('data/sm_labels_train.conll', 'w') as trainlabelf:
            with open('data/sm_dat_dev_a.conll', 'w') as devaf:
                with open('data/sm_dat_dev_b.conll', 'w') as devbf:
                    with open('data/sm_labels_dev.conll', 'w') as devlabelf:        
                        with open('data/sm_dat_test_a.conll', 'w') as testaf:
                            with open('data/sm_dat_test_b.conll', 'w') as testbf:
                                with open('data/sm_labels_test.conll', 'w') as testlabelf:
                                    file_dict = {
                                        'train': {'fa': trainaf, 'fb': trainbf, 'flab': trainlabelf},
                                        'dev': {'fa': devaf, 'fb': devbf, 'flab': devlabelf},
                                        'test': {'fa': testaf, 'fb': testbf, 'flab': testlabelf}
                                    }
                                    tok_conll = quora.head(5000).apply(lambda x: tokenize_quora_row(x, file_dict), axis=1)
# Out:
# time: 2.35 s
